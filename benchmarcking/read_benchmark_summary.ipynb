# %%
import pandas as pd

# %%
file="benchmark_summary.csv"

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#                                 Model                        Start Time  \
# 0                      mistral:latest  2025-09-30 18:07:02.664000+00:00
# 1                             mistral  2025-09-30 05:01:03.549000+00:00
# 2                            llama3.1  2025-09-29 00:15:05.913000+00:00
# 3                             mistral  2025-09-29 00:39:12.264000+00:00
# 4                      mistral:latest  2025-10-01 16:59:59.285000+00:00
# 5                     llama3.1:latest  2025-10-01 17:32:16.677000+00:00
# 6                            llama3.1  2025-09-30 04:36:31.794000+00:00
# 7                     llama3.1:latest  2025-10-01 08:11:38.569000+00:00
# 8                      mistral:latest  2025-09-30 19:25:36.629000+00:00
# 9                     llama3.1:latest  2025-09-30 19:56:28.579000+00:00
# 10                        deepseek-r1  2025-09-30 06:13:54.651000+00:00
# 11                        deepseek-r1  2025-09-30 05:56:59.182000+00:00
# ...

# %%
df.to_excel("benchmark_summary.xlsx")
